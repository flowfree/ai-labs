# %% [markdown]
# # Text to Speech
#
# Speech to Text using [microsoft/speecht5_tts](https://huggingface.co/microsoft/speecht5_tts) model. The code below is copied from the model card.

# %% [markdown]
# Load the model:

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech

processor = SpeechT5Processor.from_pretrained('microsoft/speecht5_tts')
model = SpeechT5ForTextToSpeech.from_pretrained('microsoft/speecht5_tts')

# %% [markdown]
# Load a speaker embedding:

# %%
from datasets import load_dataset
import torch 

embeddings_dataset = load_dataset('Matthijs/cmu-arctic-xvectors', split='validation')
speaker_embeddings = torch.tensor(embeddings_dataset[7306]['xvector']).unsqueeze(0)
speaker_embeddings.shape

# %% [markdown]
# Load a vocoder:

# %%
from transformers import SpeechT5HifiGan

vocoder = SpeechT5HifiGan.from_pretrained('microsoft/speecht5_hifigan')

# %% [markdown]
# Preprocess the input text:

# %%
text = "Don't count the days, make the days count."
inputs = processor(text=text, return_tensors='pt')

# %%
speech = model.generate_speech(inputs['input_ids'], speaker_embeddings, vocoder=vocoder)

# %%
from IPython.display import Audio

Audio(speech, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import soundfile as sf

dst = '../media/text-to-speech-output.wav'
sf.write(dst, speech.numpy(), samplerate=16000)
